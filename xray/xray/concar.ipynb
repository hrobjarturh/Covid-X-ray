# %%
from pgrace.rules import create_report, get_ruleset_reports, get_project_rulesets
from pgrace import concar
from datetime import datetime
import pandas as pd
import pgrace
import dateutil.parser as dparser
# Out:
# 2022-11-02 18:07:33,030:pgrace.concar.__private:INFO> loaded concar config
# 2022-11-02 18:07:33,031:pgrace.concar.__private:INFO> set log level to INFO
# 2022-11-02 18:07:33,032:pgrace.concar.__private:INFO> session ID: 6805e1a2-8737-4c6c-8d6f-3a6a224c22d7
# 2022-11-02 18:07:33,034:pgrace.concar.__private:INFO> concar initialized

# %%
pgrace.concar.__name__
# Out:
# 'pgrace.concar'

# %%
dir(pgrace.concar)
# Out:
# ['Event',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__private',
#  '__spec__',
#  'event',
#  'events',
#  'get_events',
#  'send_generic_event',
#  'send_notification_event',
#  'send_sql_query_event']

# %%
pd.options.display.max_columns = None

# %%
concar.get_events.__code__.co_varnames
# Out:
# ('start_date',
#  'end_date',
#  'name',
#  'gov_stream',
#  'artifact',
#  'category',
#  'user',
#  'standardized')

# %%
logs = concar.get_events(datetime(2022, 1, 9), datetime.today())

# %%
logs
# Out:
# [{'id': '57265825-c9b3-44f6-b4d2-fefcad801502',
#   'name': 'startWorkspace',
#   'type': 'System',
#   'category': 'Administration',
#   'userId': 'hho',
#   'createdDate': '2022-09-22T09:24:35.44296704Z',
#   'data': {'artifacts': None,
#    'standardized': None,
#    'system.event': [{'name': 'id',
#      'type': 'string',
#      'stringValue': 'workspace-f907738c-146c-4ca3-83c4-4f62ef99ea60'},
#     {'name': 'projectName', 'type': 'string', 'stringValue': 'monpolydev'},
#     {'name': 'username', 'type': 'string', 'stringValue': 'hho'},
#     {'name': 'cpu', 'type': 'number', 'numValue': 1000},
#     {'name': 'gpu', 'type': 'bool', 'boolValue': False},
#     {'name': 'memory', 'type': 'number', 'numValue': 3000},
#     {'name': 'imageName',
#      'type': 'string',
#      'stringValue': 'registry.internal.2021.services/common/jupyter/python3.8:1.1.11'},
#     {'name': 'libImageName', 'type': 'string', 'stringValue': ''},
# ...

# %%
list_of_events = concar.get_events(
    start_date=datetime.today().date(),
    end_date=datetime.now(),
    name='uat-event'
)

# %%
event = concar.Event('biomodelt7')

# %%
# Model is deployed (automatic)
event.SetCustomStr1('modelDeployment')
event.SetCustomNum1(1.)
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-11-02 18:10:05,247:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# 2022-11-02 18:10:05,258:pgrace.concar.__private:INFO> sending message (601 bytes): {"id": "2c9f37f6-8afc-4931-8e29-7fb07dd11e4f", "@timestamp": 1667412605236.0293, "auth": {"username": "hho"}, "project": {"name": "monpolydev", "id": ""}, "source": "Workspace", "emitter": "workspace-hhod1ab", "type": "Code", "comment": "", "code": {"sessionId": "6805e1a2-8737-4c6c-8d6f-3a6a224c22d7", "gitCommit": "", "function": "concar.send_generic_event", "source": "/usr/local/lib/python3.8/dist-packages/pgrace/concar/event.py"}, "artifacts": {}, "name": "biomodelt7", "category": "Generic", "govStream": "", "artifact": "", "standardized": {"customNum1": 1.0, "customStr1": "modelDeployment"}}
# ...

# %% [markdown]
# ### For high-risk AI systems: Biometric identification and categorisation of natural persons intended to be used for the ‘real-time’ and ‘post’ remote biometric identification of natural persons; of Annex III, the logging capabilities shall provide, at a minimum:
# (a) recording of the period of each use of the system (start date and time and end
# date and time of each use);
#
# (b) the reference database against which input data has been checked by the
# system;
#
# (c) the input data for which the search has led to a match;
#
# (d) the identification of the natural persons involved in the verification of the
# results, as referred to in Article 14 (5).

# %% [markdown]
# ## pgrace documentation:
# Administration events are Project Specific System events that are generated and logged when project specific events occur, such as
# * Users are added to a project
# * Data Sources are added and used.
# * Models Deployed

# %%
event = concar.Event('biomodelt6')

# %%
# Model is deployed (automatic)
event.SetGovStream('admin')
event.SetCustomStr1('modelDeployment')
event.SetCustomNum1(1.)
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:26,800:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
# Model is used
# example: correct logs
event.SetGovStream('models')
event.SetCustomStr1('modelUse')
event.SetCustomNum1(1.)
event.SetLink("1234")
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:27,496:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
# Db is used (automatic)
event.SetGovStream('database')
event.SetCustomStr1('dbUsed')
event.SetCustomNum1(1.)
event.SetLink("1234")
event.SetJSONDoc({'x': 1.3,'y': 2.3})
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:27,983:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
# Model is stop being used
event.SetGovStream('models')
event.SetCustomStr1('modelUse')
event.SetCustomNum1(0.)
event.SetLink("1234")
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:28,160:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
# results are verified
event.SetGovStream('oversight')
event.SetCustomStr1('verification')
event.SetCustomStr2('hho')
event.SetLink("1234")
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:28,360:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
# Model is used
# example: no match found (correct logs)
event.SetGovStream('models')
event.SetCustomStr1('modelUse')
event.SetCustomNum1(1.)
event.SetLink("2345")
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:28,756:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
# Db is used (automatic)
event.SetGovStream('database')
event.SetCustomStr1('dbUsed')
event.SetCustomNum1(0.)
event.SetJSONDoc({})
event.SetLink("2345")
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:28,953:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
# Model is stop being used
event.SetGovStream('models')
event.SetCustomStr1('modelUse')
event.SetCustomNum1(0.)
event.SetLink("2345")
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:29,130:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
# Model is used
# example: missing verification
event.SetGovStream('models')
event.SetCustomStr1('modelUse')
event.SetCustomNum1(1.)
event.SetLink("2345")
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:29,417:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
# Db is used (automatic)
event.SetGovStream('database')
event.SetCustomStr1('dbUsed')
event.SetCustomNum1(1.)
event.SetLink("2345")
event.SetJSONDoc({'x': 1.7,'y': 2.5})
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:29,665:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
# Model is stop being used
event.SetGovStream('models')
event.SetCustomStr1('modelUse')
event.SetCustomNum1(0.)
event.SetLink("2345")
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:30,059:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
# Model is used
# example: missing input data
event.SetGovStream('models')
event.SetCustomStr1('modelUse')
event.SetCustomNum1(1.)
event.SetLink("2345")
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:30,269:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
# Db is used (automatic)
event.SetGovStream('database')
event.SetCustomStr1('dbUsed')
event.SetCustomNum1(1.)
event.SetJSONDoc({})
event.SetLink("2345")
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:30,510:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
# results are verified
event.SetGovStream('oversight')
event.SetCustomStr1('verification')
event.SetCustomStr2('hho')
event.SetLink("2345")
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:30,711:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
# Model is stop being used
event.SetGovStream('models')
event.SetCustomStr1('modelUse')
event.SetCustomNum1(0.)
event.SetLink("2345")
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:31,092:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
# Model is removed (automatic)
event.SetGovStream('admin')
event.SetCustomStr1('modelDeployment')
event.SetCustomNum1(0.)
event.SetLink("2345")
event.SendAndClear()
# Out:
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# 2022-09-22 15:01:31,384:pgrace.concar.__private:WARNING> failed to determine git commit: Command '['git', 'rev-parse', 'HEAD']' returned non-zero exit status 128.
# ...

# %%
list_of_events = concar.get_events(
    start_date=datetime(2022, 8, 1),
    end_date=datetime.now(),
    name='biomodelt6',
)
list_of_events.reverse()

# %%
list_of_events
# Out:
# [{'id': '7efa56cc-a710-4753-8a5f-771c3f022329',
#   'name': 'biomodelt6',
#   'type': 'Code',
#   'category': 'Generic',
#   'userId': 'hho',
#   'createdDate': '2022-09-22T15:01:26.771797248Z',
#   'data': {'artifacts': {'in': None, 'out': None},
#    'code.args': None,
#    'code.function': 'concar.send_generic_event',
#    'code.gitCommit': '',
#    'code.result': None,
#    'code.source': '/usr/local/lib/python3.8/dist-packages/pgrace/concar/event.py',
#    'standardized': {'link': '1234',
#     'customNum1': 1,
#     'customStr1': 'modelDeployment'}},
#   'projectId': 'monpolydev',
#   'sessionId': 'e426d837-34ca-48f6-91a8-ecdd9a24f5a3',
#   'eventEmitterId': 'workspace-hhod1ab',
#   'comment': '',
#   'govStream': 'admin',
#   'artifact': ''},
#  {'id': '19cc0ea0-b5aa-4f0e-9466-0a9b057485d6',
#   'name': 'biomodelt6',
#   'type': 'Code',
#   'category': 'Generic',
#   'userId': 'hho',
#   'createdDate': '2022-09-22T15:01:27.473488384Z',
# ...

# %%
import logging

# %%
time

# %%
list_of_events[0]['data']['standardized']['link']
# Out:
# '1234'
